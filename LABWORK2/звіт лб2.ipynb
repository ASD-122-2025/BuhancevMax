# %% [markdown]
# 1. Перевірив версію Anaconda![1 перевірив версію conda .png](attachment:819d0c08-f372-422c-b4f5-88e1730c901e.png)

# %% [markdown]
# 2. Перевірив версію Python![2 перевірив версію python.png](attachment:cf27149d-4300-4605-bd23-b2a235e79b2c.png)

# %% [markdown]
# 3. Оновив усе середовище![3 оновив усе середовище.png](attachment:9a829958-a413-4f7b-8079-5c14ffe68b2e.png)

# %% [markdown]
# 4. Створив своє середовище ![4 створив свое середовище.png](attachment:52f3c6b2-377f-40c8-94aa-ede5edd558c7.png)

# %% [markdown]
# 5. Активував середовище
# ![5 активував своє середовище.png](attachment:26f5f895-983a-4821-9c01-4d116fb92f32.png)

# %% [markdown]
# 6. Встановив numpy та matplotlib ![6 встановив numpy та matplotlib.png](attachment:1d05bba5-f010-4c24-ad5c-5357ec235200.png)

# %% [markdown]
# 7. Створив документ Jupyter ![7 створив документ юпітер.png](attachment:848c4356-d851-48c1-9f9d-a6dcf56a39b3.png)

# %% [markdown]
# 8. Перевірив працездатність ![8 перевірив працездатність.png](attachment:88e43d6c-4c43-4a6d-bd57-71f61daa568a.png)
